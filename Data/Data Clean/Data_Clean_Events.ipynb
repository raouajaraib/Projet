# %%
import pandas as pd
import countries
from geopy.geocoders import Nominatim

# %%
file_path="C:/Users/veroj/OneDrive/Mis Documentos/POEI Data Engenieer/Projet POEI\Projet Meteo/Data/Disasters_Historique.csv"

# %%
# Reading csv file

data = pd.read_csv(file_path, sep=';')

data.head()
# Out:
#     disaster_num  date_event date_event_fin disaster_group disaster_type  \
# 0  1970-0001-MAR  1970-01-22     1970-01-22   Hydrologique    Inondation
# 1  1970-0002-PER  1970-01-01     1970-01-01   Hydrologique    Inondation
# 2  1970-0004-PHL  1970-04-07     1970-04-07    Geophysique   Tremblement
# 3  1970-0010-CHN  1970-01-04     1970-01-04    Geophysique   Tremblement
# 4  1970-0013-ARG  1970-01-04     1970-01-04   Hydrologique    Inondation
#
#    disaster_subtype disaster_subsubtype event_nom  ID_Continent ISO_3  \
# 0               NaN                 NaN       NaN           2.0   MAR
# 1               NaN                 NaN       NaN           5.0   PER
# 2  Mouvement au sol                 NaN       NaN           1.0   PHL
# 3  Mouvement au sol                 NaN       NaN           1.0   CHN
# 4               NaN                 NaN       NaN           5.0   ARG
#
#    nom_continent         pays                                location  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5704 entries, 0 to 5703
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   disaster_num         5704 non-null   object
#  1   date_event           5704 non-null   object
#  2   date_event_fin       5704 non-null   object
#  3   disaster_group       5704 non-null   object
#  4   disaster_type        5704 non-null   object
#  5   disaster_subtype     4136 non-null   object
#  6   disaster_subsubtype  380 non-null    object
#  7   event_nom            1090 non-null   object
#  8   ID_Continent         5506 non-null   float64
#  9   ISO_3                5693 non-null   object
#  10  nom_continent        5506 non-null   object
#  11  pays                 5544 non-null   object
#  12  location             4791 non-null   object
#  13  disaster_magnitude   1708 non-null   float64
#  14  magnitude_scale      5135 non-null   object
# ...

# %%
from dataclasses import replace

data["latitude"] = replace(data["latitude"], ',','.')
data["longitude"] = replace(data["longitude"], ',','.')
data["latitude"] = data.latitude.astype(float)
data["longitude"] = data.longitude.astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 3
#       1 from dataclasses import replace
# ----> 3 data["latitude"] = str.replace(data["latitude"], ',','.')
#       4 data["longitude"] = str.replace(data["longitude"], ',','.')
#       5 data["latitude"] = data.latitude.astype(float)
#
# TypeError: descriptor 'replace' for 'str' objects doesn't apply to a 'Series' object

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

def geo_name(lat, lon): 
        #location = geolocator.reverse(lat+","+lon)
        #address = location.raw['address']
        #country = address.get('country', '')
        country = countries.CountryChecker('TM_WORLD_BORDERS-0.3.shp')
        country.getCountry(countries.Point(lat, lon)).iso
        return country

#cc = countries.CountryChecker('TM_WORLD_BORDERS-0.3.shp')
#print cc.getCountry(countries.Point(49.7821, 3.5708)).iso

# %%
data.apply(geo_name, args = (7,8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [46], line 1
# ----> 1 data.apply(geo_name, args = (7,8))
#
# AttributeError: 'dict' object has no attribute 'apply'
